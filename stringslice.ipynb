# %%
from collections import OrderedDict
def merge_the_tools(string, k):
    # your code goes here
    #size = int(len(string)//k)
    #print("size is ",size)
    size =k
    start = 0
    while((start+size) <= len(string)):
        newstart = start+size
        strs = string[start:newstart]
        p = "".join(OrderedDict.fromkeys(strs))  
        print(p)
        start = newstart 

merge_the_tools("AABCAAADA",3)
# Out:
# AB
# CA
# AD

# %%
string="..."
k=3452
merge_the_tools(string,k)
# Out:
# KYQTWXDLINFBHRGZVCUSAMOEPJ
# YUGTZIWNVSALBXOCDMPFEKJRQH
