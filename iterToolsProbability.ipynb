# %%
from itertools import combinations
b = int(input())
lst = list(input().split())
k= int(input())
t = combinations(lst,k)
m =0
c=0
for i in combinations(lst,k):
    if('a' in i):
        m +=1
    c += 1
prob = m/c
print("{:.4f}".format(prob))
# Out:
# 9
# a b c a d b z e o
# 4
# ('a', 'b', 'c', 'a')
# ('a', 'b', 'c', 'd')
# ('a', 'b', 'c', 'b')
# ('a', 'b', 'c', 'z')
# ('a', 'b', 'c', 'e')
# ('a', 'b', 'c', 'o')
# ('a', 'b', 'a', 'd')
# ('a', 'b', 'a', 'b')
# ('a', 'b', 'a', 'z')
# ('a', 'b', 'a', 'e')
# ('a', 'b', 'a', 'o')
# ('a', 'b', 'd', 'b')
# ('a', 'b', 'd', 'z')
# ('a', 'b', 'd', 'e')
# ('a', 'b', 'd', 'o')
# ('a', 'b', 'b', 'z')
# ('a', 'b', 'b', 'e')
# ('a', 'b', 'b', 'o')
# ('a', 'b', 'z', 'e')
# ('a', 'b', 'z', 'o')
# ('a', 'b', 'e', 'o')
# ('a', 'c', 'a', 'd')
# ('a', 'c', 'a', 'b')
# ('a', 'c', 'a', 'z')
# ('a', 'c', 'a', 'e')
# ('a', 'c', 'a', 'o')
# ('a', 'c', 'd', 'b')
# ('a', 'c', 'd', 'z')
# ('a', 'c', 'd', 'e')
# ('a', 'c', 'd', 'o')
# ('a', 'c', 'b', 'z')
# ('a', 'c', 'b', 'e')
# ('a', 'c', 'b', 'o')
# ('a', 'c', 'z', 'e')
# ('a', 'c', 'z', 'o')
# ('a', 'c', 'e', 'o')
# ('a', 'a', 'd', 'b')
# ('a', 'a', 'd', 'z')
# ('a', 'a', 'd', 'e')
# ('a', 'a', 'd', 'o')
# ('a', 'a', 'b', 'z')
# ('a', 'a', 'b', 'e')
# ...
